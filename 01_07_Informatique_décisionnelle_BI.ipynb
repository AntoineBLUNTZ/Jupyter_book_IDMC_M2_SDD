# %% [markdown]
# ---
# title: Tableau de bord Power BI
# subtitle: Cours d'Informatique décisionnelle du Master 2 SDD  à l'IDMC
# authors:
#   - name: Kamel SMAÏLI
#     email: smaili@loria.fr
#     affiliations:
#       - name: Université de Lorraine, FRANCE
#         ror: 04vfs2w97
# date: 2023-01-23
# ---

# %%
from powerbiclient import Report, models

# %%
# Import the DeviceCodeLoginAuthentication class to authenticate against Power BI
from powerbiclient.authentication import DeviceCodeLoginAuthentication

# Initiate device authentication
device_auth = DeviceCodeLoginAuthentication()
# Out:
# Performing device flow authentication. Please follow the instructions below.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code LAXAX629C to authenticate.
#
# Device flow authentication successfully completed.
# You are now logged in .
#
# The result should be passed only to trusted code in your notebook.

# %%
group_id="4bec0c1d-f3b8-4859-8e03-ac72f96d981a"
report_id="999d9a45-1f7b-4a03-af7a-af945839efc4"

# %%
report = Report(group_id=group_id, report_id=report_id, auth=device_auth)

report
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File c:\Users\antoi\AppData\Local\Programs\Python\Python312\Lib\site-packages\powerbiclient\report.py:268, in Report.__init__(self, group_id, report_id, auth, view_mode, permissions, dataset_id, **kwargs)
#     267         response_key = "embedUrl"
# --> 268     embed_url = self._get_embed_url(
#     269         request_url=request_url, token=access_token, response_key=response_key)
#     271 except Exception as ex:
#
# File c:\Users\antoi\AppData\Local\Programs\Python\Python312\Lib\site-packages\powerbiclient\report.py:309, in Report._get_embed_url(self, request_url, token, response_key)
#     308 if not response.ok:
# --> 309     raise Exception(
#     310         "Get embed URL failed with status code {0}".format(response.status_code))
#     311 return response.json()[response_key]
#
# ...
