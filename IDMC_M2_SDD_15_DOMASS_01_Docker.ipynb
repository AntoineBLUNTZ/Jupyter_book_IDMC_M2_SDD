# %% [markdown]
# ---
# title: 15.1. Docker 🐋
# subtitle: Présentation
# subject: Docker présentation
# description: bla bla bla.
# date: 2025-09-13
# authors:
#   - name: Chahrazed Labba
#     email: chahrazed.labba@univ-lorraine.fr
#     affiliations:
#       - name: Université de Lorraine
#         ror: 04vfs2w97
# thumbnail: /thumbnails/jaccepte.png
# ---

# %% [markdown]
# # <span style="color:deepskyblue">**Docker : un environnement de virtualisation léger pour préparer les environnements de données massives**</span>

# %% [markdown]
# % Exemple de données
# :::{figure} ./media/images/docker_official_logo_icon_169250.png
# :label: fig:docker
#
# Docker offical logo
# :::

# %%
import base64
from IPython.display import IFrame

# set PDF path
pdf_path = r"media/pdf/dockerFinal.pdf"

# open PDF
with open(pdf_path, "rb") as pdf:
    content = pdf.read()

# encode PDF
base64_pdf = base64.b64encode(content).decode("utf-8")

# display encoded PDF
IFrame(f"data:application/pdf;base64,{base64_pdf}", width=585, height=450)
# Out:
#         <iframe
#             width="585"
#             height="450"
#             src="data:application/pdf;base64,..."
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # <span style="color:deepskyblue">**À propos de ce cours**</span>

# %% [markdown]
# ## **Organisation du cours**

# %% [markdown]
# - **<span style="color:deepskyblue">Docker</span>** &nbsp; Préparer et gérer des environnements reproductibles pour les TPs
# - **<span style="color:deepskyblue">Introduction aux données massives</span>** &nbsp; Définition, caractéristiques (les 3V,5V, ..), enjeux et applications
# - **<span style="color:deepskyblue">Mouvement NoSQL</span>** &nbsp; Nouvelles bases de données adaptées aux données massives
# - **<span style="color:deepskyblue">Hadoop</span>** &nbsp; Écosystème de stockage et de traitement distribué
# - **<span style="color:deepskyblue">Apache Spark</span>** &nbsp; Traitement des données en mémoire, batch et streaming
# - **<span style="color:deepskyblue">Architectures Big Data</span>** &nbsp; Data Lake, Data Warehouse, Lambda et Kappa
# - un **<span style="color:deepskyblue">projet à réaliser</span>**

# %% [markdown]
# ## **Sources et références**

# %% [markdown]
# - Docker Documentation, https://docs.docker.com/
# - Docker et conteneurs : Architectures, développement, usages et outils Cloux, Pierre-Yves; Garlot, Thomas; Kohler, Johann
# - Comprendre Docker - Prise en main des conteneurs, Jean-Philippe GOUIGOUX

# %% [markdown]
# # <span style="color:deepskyblue">**Prise en main de Docker**</span>

# %% [markdown]
# ## **Installer Docker sur votre machine**

# %% [markdown]
# - Créer un compte sur Docker Hub :
# https://app.docker.com/signup
# - Installer Docker Desktop :
# Windows : https://docs.docker.com/desktop/setup/install/windows-install/
# Mac : https://docs.docker.com/desktop/setup/install/mac-install/

# %% [markdown]
# ## **Tester l'installation : Hello World**

# %% [markdown]
# - But :
#   - Vérifier que Docker est bien installé et fonctionne
#   - Valider toute la chaîne logicielle (client ↔ daemon ↔ registry ↔ conteneur)
# - Commande à exécuter :
# ```bash
# docker run hello-world
# ```
# - Résultat attendu :
#   - Téléchargement de l’image `hello-world` depuis Docker Hub
#   - Création et exécution d’un conteneur minimaliste
#   - Affichage d’un message de bienvenue confirmant l’installation

# %% [markdown]
# % Exemple de données
# :::{figure} \media\images\Docker_test_installation_fello-world.png
# :label: fig:docker_test
#
# Confirmation de l'installation de l'image `hello-world` depuis Docker Hub
# :::

# %% [markdown]
# ## **Lancer un conteneur Docker (Ubuntu)**

# %% [markdown]
# - Ouvrir un terminal
# - Télécharger une image Ubuntu :
# ```bash
# docker pull ubuntu
# ```
# % Exemple de données
# :::{figure} \media\images\Docker_pull_ubuntu.png
# :label: fig:docker_pull_ubuntu
#
# Confirmation de l'installation de l'image `ubuntu` depuis Docker Hub
# :::
# - Lister les images disponibles :
# ```bash
# docker images
# ```
# % Exemple de données
# :::{figure} \media\images\Docker_images.png
# :label: fig:docker_images
#
# Liste des images Docker créées le plus récemment.
# :::
# - Lancer un conteneur interactif :
# ```bash
# docker run -it ubuntu
# ```
# ou
# ```bash
# winpty docker run -it ubuntu
# ```
# % Exemple de données
# :::{figure} \media\images\Docker_run.png
# :label: fig:docker_run
#
# Lancement d'un conteneur interactif et exécutuion de commandes Ubuntu
# :::

# %% [markdown]
# Docker_images.png

# %% [markdown]
# ::::{important} Objective
#
# The goal of this quickstart is to get you up and running in [JupyterLab](https://jupyter.org), explore inline execution 📈, and working together with other MyST tools.
#
# For this tutorial we are assuming some familiarity with [JupyterLab](https://jupyter.org), and MyST syntax (see the [MyST quickstart guide](./quickstart-myst-markdown.md)). We will be executing a few Python code cells in the notebook, familiarity with `numpy` and `matplotlib` is helpful but not necessary.
# ::::

# %%
import altair as alt
from vega_datasets import data

source = data.cars()
brush = alt.selection_interval(encodings=['x'])
points = alt.Chart(source).mark_point().encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    size='Acceleration',
    color=alt.condition(brush, 'Origin:N', alt.value('lightgray'))
).add_params(brush)

bars = alt.Chart(source).mark_bar().encode(
    y='Origin:N',
    color='Origin:N',
    x='count(Origin):Q'
).transform_filter(brush)

# %%
points & bars
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# <br><br><br>
