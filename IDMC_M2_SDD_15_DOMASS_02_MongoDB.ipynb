# %% [markdown]
# ---
# title: 15.2. MongoDB 🥬
# date: 2024-06-12
# authors:
#   - name: Chahrazed Labba
#     email: chahrazed.labba@univ-lorraine.fr
#     affiliations:
#       - name: Université de Lorraine
#         ror: 04vfs2w97
# ---

# %% [markdown]
# # **15.2. MongoDB**

# %% [markdown]
# % Exemple de données
# :::{figure} media\images\mongodb_original_wordmark_logo_icon_146425.png
# :label: fig:mongoDB
#
# MongoDB offical logo
# :::
